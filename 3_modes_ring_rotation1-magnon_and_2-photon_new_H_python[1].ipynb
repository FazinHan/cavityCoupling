# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
sp.init_printing()

# Define other symbolic variables
b1,b2,b3,w,w1,w2,w3,a,b,v,v1,v2,v3,g1,g2,g3,pin,pout,s21,H = sp.symbols('b_1,b_2,b_3,w,w_1,w_2,w_3,a,b,v,v_1,v_2,v_3,g_1,g_2,g_3,p_{in},p_{out},s_{21},H')
#a=alpha b=beta v=gamma,v1=gamma1,v2=gamma2,v3=gamma3 b1,b2=annihilation op for magnon and b3= annihilattion op for photon
# Define imaginary unit
j = sp.I

# Define equations
eq11 = sp.Eq(j*((w-w1+j*a)*b1)-j*g2*b2-j*g3*b3-j*(sp.sqrt(v1)*pin)-v1*b1-sp.sqrt(v1*v2)*b2-sp.sqrt(v1*v3)*b3, 0)
eq22 = sp.Eq(j*((w-w2+j*b)*b2)-j*g1*b3-j*g2*b1-j*(sp.sqrt(v2)*pin)-sp.sqrt(v1*v2)*b1-v2*b2-sp.sqrt(v2*v3)*b3, 0)
eq33 = sp.Eq(j*((w-w3+j*v)*b3)-j*g1*b2-j*g3*b1-j*(sp.sqrt(v3)*pin)-sp.sqrt(v1*v3)*b1-sp.sqrt(v2*v3)*b2-v3*b3, 0)

eq44 = sp.Eq(j*((w-w1+j*a)*b1)-j*g2*b2-j*g3*b3-j*(sp.sqrt(v1)*pout)+v1*b1+sp.sqrt(v1*v2)*b2+sp.sqrt(v1*v3)*b3, 0)
eq55 = sp.Eq(j*((w-w2+j*b)*b2)-j*g1*b3-j*g2*b1-j*(sp.sqrt(v2)*pout)+sp.sqrt(v1*v2)*b1+v2*b2+sp.sqrt(v2*v3)*b3, 0)
eq66 = sp.Eq(j*((w-w3+j*v)*b3)-j*g1*b2-j*g3*b1-j*(sp.sqrt(v3)*pout)+sp.sqrt(v1*v3)*b1+sp.sqrt(v2*v3)*b2+v3*b3, 0)
eq7 = sp.Eq(s21, (pout/pin)-1)

#eq6

# %%
#t = 0
t = sp.pi/3
v1_value=0.0001     #gamma1 extrinsic damping of magnon1 mode 
v2_value=0.008 * (sp.cos(t))**2      #gamma1 extrinsic damping of magnon2 mode
v3_value=0.02 * (sp.sin(t))**2      #gamma1 extrinsic damping of cavity mode

# w2_value=3.9790176    # cavity 2 resonance frequency
w3_value=5.71             # cavity 3 resonance frequency

a_value=0.00014  # intrinsic damping of magnon1 mode
b_value=0.00369 # intrinsic damping of magnon2 mode
v_value=0.005268  # intrinsic damping of cavity mode

g1_value=0.038
g2_value=0.033
g3_value=0.058


# eq1=eq11.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq2=eq22.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq3=eq33.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

# eq4=eq44.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq5=eq55.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq6=eq66.subs({v1:v1_value,v2:v2_value,v3:v3_value,w2:w2_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

# eq1=eq11.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq2=eq22.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq3=eq33.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

# eq4=eq44.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq5=eq55.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
# eq6=eq66.subs({v1:v1_value,v2:v2_value,v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

eq1=eq11.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
eq2=eq22.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
eq3=eq33.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

eq4=eq44.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
eq5=eq55.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})
eq6=eq66.subs({v3:v3_value,w3:w3_value,a:a_value,b:b_value,v:v_value,g1:g1_value,g2:g2_value,g3:g3_value})

# %%
# Solve eq1 for b1 in terms of b2 and b3
sol_b1 = sp.nsolve(eq1, (b1,v1,v2))[0]

# Substitute sol_b1 into eq2 and solve for b2 in terms of b3
eq2_sub = eq2.subs(b1, sol_b1)
sol_b2 = sp.solve(eq2_sub, (v1,v2,b2))[0]

# Substitute sol_b1 and sol_b2 into eq3 and solve for b3
eq3_sub = eq3.subs({b1: sol_b1, b2: sol_b2})
sol_b3 = sp.solve(eq3_sub, (v1,v2,b3))[0]

# Substitute sol_b3 back into sol_b2 to get the final expression for b2
sol_b2_final = sol_b2.subs(b3, sol_b3)

# Substitute sol_b3 and sol_b2_final back into sol_b1 to get the final expression for b1
sol_b1_final = sol_b1.subs({b2: sol_b2_final, b3: sol_b3})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Solve eq1 for b1 in terms of b2 and b3
# ----> 2 sol_b1 = sp.nsolve(eq1, (b1,v1,v2))[0]
#       4 # Substitute sol_b1 into eq2 and solve for b2 in terms of b3
#       5 eq2_sub = eq2.subs(b1, sol_b1)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\utilities\decorator.py:87, in conserve_mpmath_dps.<locals>.func_wrapper(*args, **kwargs)
#      85 dps = mpmath.mp.dps
#      86 try:
# ---> 87     return func(*args, **kwargs)
#      88 finally:
#      89     mpmath.mp.dps = dps
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\solvers\solvers.py:3035, in nsolve(dict, *args, **kwargs)
#    3033     fargs = syms.copy().pop()
#    3034 if not (len(syms) == 1 and (fargs in syms or fargs[0] in syms)):
# -> 3035     raise ValueError(filldedent('''
#    3036         expected a one-dimensional and numerical function'''))
#    3038 # the function is much better behaved if there is no denominator
#    3039 # but sending the numerator is left to the user since sometimes
#    3040 # the function is better behaved when the denominator is present
#    3041 # e.g., issue 11768
#    3043 f = lambdify(fargs, f, modules)
#
# ValueError:
# expected a one-dimensional and numerical function

# %%
# Compute the difference between eq1 and eq3
difference_eq1_eq3 = eq1.lhs - eq4.lhs

# Define the new equation
new_eq = sp.Eq(difference_eq1_eq3, 0)

# %%
# Substitute the values of a and b into new_eq
new_eq_substituted = new_eq.subs({b1: sol_b1_final, b2: sol_b2_final, b3: sol_b3})

# %%
solution3 = sp.nsolve(new_eq_substituted, pout)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 solution3 = sp.solve(new_eq_substituted, pout)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\solvers\solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\solvers\solvers.py:1434, in _solve(f, *symbols, **flags)
#    1431 elif f_num.is_Symbol:
#    1432     # no need to check but simplify if desired
#    1433     if flags.get('simplify', True):
# -> 1434         sol = simplify(sol)
#    1435     return [{f_num: sol}]
#    1437 poly = None
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\simplify\simplify.py:644, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     642 expr = _bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     643 expr = Mul(*powsimp(expr).as_content_primitive())
# --> 644 _e = cancel(expr)
#     645 expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     646 expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\polytools.py:6890, in cancel(f, _signsimp, *gens, **args)
#    6887                 pass
#    6888         return f.xreplace(dict(reps))
# -> 6890 c, (P, Q) = 1, F.cancel(G)
#    6891 if opt.get('polys', False) and 'gens' not in opt:
#    6892     opt['gens'] = R.symbols
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\rings.py:2193, in PolyElement._gcd(f, g)
#    2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
# -> 2193     return ring.dmp_inner_gcd(f, g)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\compatibility.py:663, in IPolys.dmp_inner_gcd(self, f, g)
#     662 def dmp_inner_gcd(self, f, g):
# --> 663     H, F, G = dmp_inner_gcd(self.to_dense(f), self.to_dense(g), self.ngens-1, self.domain)
#     664     return (self.from_dense(H), self.from_dense(F), self.from_dense(G))
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1557, in _dmp_inner_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
# -> 1557 return dmp_rr_prs_gcd(f, g, u, K)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1068, in dmp_rr_prs_gcd(f, g, u, K)
#    1065 fc, F = dmp_primitive(f, u, K)
#    1066 gc, G = dmp_primitive(g, u, K)
# -> 1068 h = dmp_subresultants(F, G, u, K)[-1]
#    1069 c, _, _ = dmp_rr_prs_gcd(fc, gc, u - 1, K)
#    1071 if K.is_negative(dmp_ground_LC(h, u, K)):
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:1238, in dmp_prem(f, g, u, K)
#    1235 j, N = dr - dg, N - 1
#    1237 R = dmp_mul_term(r, lc_g, 0, u, K)
# -> 1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#    1241 _dr, dr = dr, dmp_degree(r, u)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:807, in dmp_mul(f, g, u, K)
#     793 """
#     794 Multiply dense polynomials in ``K[X]``.
#     795
#    (...)
#     804
#     805 """
#     806 if not u:
# --> 807     return dup_mul(f, g, K)
#     809 if f == g:
#     810     return dmp_sqr(f, u, K)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\densearith.py:767, in dup_mul(f, g, K)
#     764     coeff = K.zero
#     766     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 767         coeff += f[j]*g[i - j]
#     769     h.append(coeff)
#     771 return dup_strip(h)
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\domains\gaussiandomains.py:98, in GaussianElement.__mul__(self, other)
#      96 x, y = self._get_xy(other)
#      97 if x is not None:
# ---> 98     return self.new(self.x*x - self.y*y, self.x*y + self.y*x)
#      99 else:
#     100     return NotImplemented
#
# File c:\Users\freak\miniconda3\Lib\site-packages\sympy\polys\domains\gaussiandomains.py:28, in GaussianElement.new(cls, x, y)
#      25 @classmethod
#      26 def new(cls, x, y):
#      27     """Create a new GaussianElement of the same domain."""
# ---> 28     obj = super().__new__(cls)
#      29     obj.x = x
#      30     obj.y = y
#
# KeyboardInterrupt:

# %%
# Solve equation eq5 for s21 after substituting pout from solution3
solution4 = sp.solve(eq7.subs(pout, solution3[0]), s21)

# Assign the value of s21 to a variable
S = solution4[0]

display(S)

import pickle
pickle.dump(S, open('s21_analytical.p', 'wb'))

assert 0

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import pandas as pd
import os



# Define parameter ranges
type = "yig_t_0.02"


root = os.path.join("C:\\Users\\freak\\OneDrive\\Documents\\core\\Projects\\cavityCoupling","data","lone_t_sweep_yig")
file_path_full = os.path.join(root,f"{type}.csv")

full_data = pd.read_csv(file_path_full)

# Display the first few rows of the DataFrame
frequencies = full_data.to_numpy()[:,0]
# frequencies = np.linspace(4.5, 6, frequencies.size) 
Hlist = np.array(full_data.columns)[1:].astype(float) # Skip the first column which is 'Frequency'
# Hlist = np.linspace(1.050, 1.350, Hlist.size)
s21 = full_data.to_numpy()[:,1:] # Skip the first column which is 'Frequency'

# H_values = np.linspace(0.600, 1.500, 201)
H_values = Hlist
# w_values = np.linspace(3.5, 6.5, 501)
w_values = frequencies

# Convert symbolic expression s21 to a NumPy function
s21_func = sp.lambdify((w, w1, w2, v1, v2), sp.Abs(S), modules='numpy')

# Initialize a list to store s21_f
s21_f = []

# Loop over each H value
for H in H_values:
    # Calculate wb_value for the current H value
    wb1_value = 1.68e-2/2/np.pi*np.sqrt(H * (H + 1750))
    wb2_value = 2.94e-3*np.sqrt(H * (H + 10900))
    # wb_value = 2.8*np.sqrt(H * (H + 0.172))
    # w1_value=1.38284384+(3.19289744)*H
    
    # Initialize a list to store s21_3 values for the current H value
    s21_f_H = []
    
    for w_val in w_values:
        s21_2 = s21_func(w_val, wb1_value, wb2_value)
        s21_f_H.append(s21_2)
      
    # Append s21_f_H to s21_f as a row
    s21_f.append(s21_f_H)

# Convert s21_f to a numpy array and transpose it
s21_f = np.array(s21_f).T  # Transpose s21_f here
H_f = np.array(H_values)
w_f = np.array(w_values)

# %%
# Create a contour plot
#contour = plt.contourf(H_f, w_f, s21_f, )
contour = plt.contourf(H_f, w_f, s21_f, cmap='inferno', levels=np.linspace(0, 2, 501))
plt.colorbar(contour)
plt.xlabel('H')
plt.ylim([5.5,6])    
plt.ylabel('w')
# plt.title('Contour Plot of s21')
plt.tight_layout()
plt.show()

#print(s21_f)
#print(H_f)
#print(w_f)
#s21_f.shape[0]
#H_f.shape[0]
#plt.ylim([3.6, 4.4])
#plt.xlim([1250, 1450])
# plt.clim(-7, 0)
