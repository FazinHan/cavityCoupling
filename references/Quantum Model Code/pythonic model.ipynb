# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
sp.init_printing()

# Define imaginary unit
j = sp.I

a,b,c,w = sp.symbols('a,b,c,w')
# Define other symbolic variables
a1,b1,pin,pout,wa,wb,v,k,s21,H = sp.symbols('a_1,b_1,p_{in},p_{out},w_a,w_b,v,k,s_{21},H')
#a1=alpha b1=beta v=gamma a=annihilation op for photon and b= annihilattion op for magnon
b2, c1, wc, e = sp.symbols('b_2,\\delta,w_c,\\epsilon')

J0, G0, J1, G1 = sp.symbols('J_0 \\Gamma_0 J_1 \\Gamma_1')
d, d2 = J0+j*G0, J1+j*G1
# d, d2 = sp.symbols('\\Delta_1 \\Delta_2')
# b2=magnon2, delta=gamma or kappa for magnon2

# Define equations
eq1 = sp.Eq(((w-wa+a1*j)*a)*j - (sp.sqrt(v)*pin)*j - v*a - sp.sqrt(k*v)*b - sp.sqrt(k*e)*c - (sp.conjugate(d)*b + sp.conjugate(d2)*c)*j, 0)
eq2 = sp.Eq(((w-wb+b1*j)*b)*j - (sp.sqrt(k)*pin)*j - k*b - sp.sqrt(v*k)*a - sp.sqrt(v*e)*c - (d*a)*j, 0)
eq3 = sp.Eq(((w-wc+c1*j)*c)*j - (sp.sqrt(e)*pin)*j - e*c - sp.sqrt(e*v)*a - sp.sqrt(e*k)*b - (d2*a)*j, 0)

eq4 = sp.Eq(((w-wa+a1*j)*a)*j - (sp.sqrt(v)*pout)*j + v*a + sp.sqrt(k*v)*b + sp.sqrt(k*e)*c - (sp.conjugate(d)*b + sp.conjugate(d2)*c)*j, 0)
eq5 = sp.Eq(((w-wb+b1*j)*b)*j - (sp.sqrt(k)*pout)*j + k*b + sp.sqrt(v*k)*a + sp.sqrt(v*e)*c - (d*a)*j, 0)
eq6 = sp.Eq(((w-wc+c1*j)*c)*j - (sp.sqrt(e)*pout)*j + e*c + sp.sqrt(e*v)*a + sp.sqrt(e*k)*b - (d2*a)*j, 0)
eq7 = sp.Eq(s21,(pout/pin)-1)
# Print equations
#print("Equations:", eq1, eq2)
eq4
# Out:
#                                 _____       ____________                    ⎛
# a⋅v + ⅈ⋅a⋅(ⅈ⋅a₁ + w - wₐ) + b⋅╲╱ k⋅v  + c⋅╲╱ \epsilon⋅k  - ⅈ⋅p_{out}⋅√v - ⅈ⋅⎝b
#
#  ⎛__     _______⎞     ⎛__     _______⎞⎞
# ⋅⎝J₀ - ⅈ⋅\Gamma₀⎠ + c⋅⎝J₁ - ⅈ⋅\Gamma₁⎠⎠ = 0

# %%
# Solve equations
sol1 = sp.solve(eq1, b)
#solution = sp.solve([eq1, eq3], (pout))
solution1 = sp.solve( eq2.subs(b, sol1[0]), a)
solution1[0]
# Out:
#            ____________        __          _______                          __
# - ⅈ⋅b₁⋅c⋅╲╱ \epsilon⋅k  + b₁⋅c⋅J₁ - ⅈ⋅b₁⋅c⋅\Gamma₁ + b₁⋅p_{in}⋅√v - ⅈ⋅c⋅k⋅╲╱ \
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                              J
#
# __________       __         _______         ____________         __       ____
# epsilon⋅k  + c⋅k⋅J₁ - ⅈ⋅c⋅k⋅\Gamma₁ - c⋅w⋅╲╱ \epsilon⋅k  - ⅈ⋅c⋅w⋅J₁ - c⋅w⋅\Gam
# ──────────────────────────────────────────────────────────────────────────────
#     _____        __      _______               _____           __
# ₀⋅╲╱ k⋅v  + ⅈ⋅J₀⋅J₀ + J₀⋅\Gamma₀ + ⅈ⋅\Gamma₀⋅╲╱ k⋅v  - \Gamma₀⋅J₀ + ⅈ⋅\Gamma₀⋅
#
# ___           ____________           __         _______         ____________
# ma₁ + c⋅w_b⋅╲╱ \epsilon⋅k  + ⅈ⋅c⋅w_b⋅J₁ + c⋅w_b⋅\Gamma₁ + ⅈ⋅c⋅╲╱ \epsilon⋅v ⋅╲
# ──────────────────────────────────────────────────────────────────────────────
# _______
# \Gamma₀ + ⅈ⋅a₁⋅b₁ + ⅈ⋅a₁⋅k + a₁⋅w - a₁⋅w_b + ⅈ⋅b₁⋅v + b₁⋅w - b₁⋅wₐ + k⋅w - k⋅w
#
#  _____       ____________ __         ____________ _______               _____
# ╱ k⋅v  - c⋅╲╱ \epsilon⋅v ⋅J₀ + ⅈ⋅c⋅╲╱ \epsilon⋅v ⋅\Gamma₀ - √k⋅p_{in}⋅╲╱ k⋅v
# ──────────────────────────────────────────────────────────────────────────────
#                      2                                   _____ __       _____
# ₐ + v⋅w - v⋅w_b - ⅈ⋅w  + ⅈ⋅w⋅wₐ + ⅈ⋅w⋅w_b - ⅈ⋅wₐ⋅w_b + ╲╱ k⋅v ⋅J₀ - ⅈ⋅╲╱ k⋅v ⋅
#
#               __             _______
# - ⅈ⋅√k⋅p_{in}⋅J₀ - √k⋅p_{in}⋅\Gamma₀ + k⋅p_{in}⋅√v - ⅈ⋅p_{in}⋅√v⋅w + ⅈ⋅p_{in}⋅
# ──────────────────────────────────────────────────────────────────────────────
# _______
# \Gamma₀
#
#
# √v⋅w_b
# ──────

# %%
# Solve equations
sol2 = sp.solve(eq1, a)
solution2 = sp.solve( eq2.subs(a, sol2[0]), b)
solution2[0]
# Out:
#          ____________          __        _______
# - J₀⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅J₀⋅c⋅J₁ - J₀⋅c⋅\Gamma₁ - ⅈ⋅J₀⋅p_{in}⋅√v - ⅈ⋅\Gamma₀⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                           J₀⋅╲
#
#     ____________             __               _______
# c⋅╲╱ \epsilon⋅k  + \Gamma₀⋅c⋅J₁ - ⅈ⋅\Gamma₀⋅c⋅\Gamma₁ + \Gamma₀⋅p_{in}⋅√v - ⅈ⋅
# ──────────────────────────────────────────────────────────────────────────────
#  _____        __      _______               _____           __             ___
# ╱ k⋅v  + ⅈ⋅J₀⋅J₀ + J₀⋅\Gamma₀ + ⅈ⋅\Gamma₀⋅╲╱ k⋅v  - \Gamma₀⋅J₀ + ⅈ⋅\Gamma₀⋅\Ga
#
#        ____________                          ____________         ____________
# a₁⋅c⋅╲╱ \epsilon⋅v  + a₁⋅√k⋅p_{in} - ⅈ⋅c⋅v⋅╲╱ \epsilon⋅v  - c⋅w⋅╲╱ \epsilon⋅v
# ──────────────────────────────────────────────────────────────────────────────
# ____
# mma₀ + ⅈ⋅a₁⋅b₁ + ⅈ⋅a₁⋅k + a₁⋅w - a₁⋅w_b + ⅈ⋅b₁⋅v + b₁⋅w - b₁⋅wₐ + k⋅w - k⋅wₐ +
#
#           ____________         ____________   _____       _____ __         ___
#  + c⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅╲╱ \epsilon⋅k ⋅╲╱ k⋅v  - c⋅╲╱ k⋅v ⋅J₁ + ⅈ⋅c⋅╲╱ k⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   2                                   _____ __       _____ ___
#  v⋅w - v⋅w_b - ⅈ⋅w  + ⅈ⋅w⋅wₐ + ⅈ⋅w⋅w_b - ⅈ⋅wₐ⋅w_b + ╲╱ k⋅v ⋅J₀ - ⅈ⋅╲╱ k⋅v ⋅\Ga
#
# __ _______                                                              _____
# v ⋅\Gamma₁ + √k⋅p_{in}⋅v - ⅈ⋅√k⋅p_{in}⋅w + ⅈ⋅√k⋅p_{in}⋅wₐ - p_{in}⋅√v⋅╲╱ k⋅v
# ─────────────────────────────────────────────────────────────────────────────
# ____
# mma₀

# %%
# Solve equations
sol3 = sp.solve(eq1, c)
solution3 = sp.solve( eq3.subs(a, sol3[0]), b)
solution3[0]
# Out:
#
# ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                           ____
# ₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ________              __            _______       __________          ________
# silon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilo
# ──────────────────────────────────────────────────────────────────────────────
#                                    _____      __        _______             __
#                           - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k
#
# ____     __________        __       __________        _______                _
# n⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
# ___             __           _______                    ____________ __     __
# ⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \
#
# ___________                __              _______          ____________
# \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v
# ──────────────────────────────────────────────────────────────────────────────
# __________ _______     ____________   _____       ____________ __     ________
# epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilo
#
#    ____________           ____________            ____________           _____
# ⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
# ____ _______
# n⋅v ⋅\Gamma₀
#
# _______       __         _______             ____________         __
# ilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  _______                 ____________
# ⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v
# ─────────────────────────────────────

# %%
# Compute the difference between eq1 and eq3
difference_eq1_eq4 = eq1.lhs - eq4.lhs

# Define the new equation
new_eq = sp.Eq(difference_eq1_eq4, 0)
new_eq
# Print the new equation
#print("Difference between eq1 and eq3:", new_eq)
# Out:
#                _____         ____________
# -2⋅a⋅v - 2⋅b⋅╲╱ k⋅v  - 2⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅p_{in}⋅√v + ⅈ⋅p_{out}⋅√v = 0

# %%
# Substitute the values of a and b into new_eq
new_eq_substituted = new_eq.subs({a: solution1[0], b: solution2[0], c: solution3[0]})

# Print the new equation with substituted values
new_eq_substituted

import pickle


# Save the expression
with open('expressions.pkl', 'wb') as f:
    pickle.dump(expr, f)
# Out:
#                                   ⎛                      ____________ ⎛
#                                   ⎜               ⅈ⋅b₁⋅╲╱ \epsilon⋅k ⋅⎝ⅈ⋅J₁⋅a⋅
#                               2⋅v⋅⎜b₁⋅p_{in}⋅√v - ────────────────────────────
#                                   ⎜
#                                   ⎝
# -ⅈ⋅p_{in}⋅√v + ⅈ⋅p_{out}⋅√v - ────────────────────────────────────────────────
#
#
#
#
# a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                    ___________
#  ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _              __            _______       __________          ____________
#   - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  +
# ──────────────────────────────────────────────────────────────────────────────
#                   _____      __        _______             _____             _
#          - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   __________        __       __________        _______                ________
# ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilo
# ──────────────────────────────────────────────────────────────────────────────
# _           _______                    ____________ __     ____________ ______
# ₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ____                __              _______          ____________         ____
# n⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
# _     ____________   _____       ____________ __     ____________ _______
# ₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ________           ____________            ____________           ____________
# silon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        __         _______             ____________         __           ______
#  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _                 ____________⎞      ⎛
# ₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠   b₁⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ
# ─────────────────────────────── + ────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                   ____________              __            ____
#  ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gam
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          _____
#                                                                 - ⅈ⋅J₁⋅╲╱ k⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___       __________          ____________     __________        __       ____
# ma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
#       __        _______             _____             __           _______
#  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______        _______                ____________                __
# silon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#                 ____________ __     ____________ _______     ____________   __
# epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    _______          ____________         ____________           ____________
# ⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  +
# ──────────────────────────────────────────────────────────────────────────────
# ___       ____________ __     ____________ _______
# ⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           ____________           ____________       __         _______
#  ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ____________         __           _______                 ____________⎞ _
# _c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅J
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _        ⎛
# ₁   ⅈ⋅b₁⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a
# ─ - ──────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delt
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       ____________              __            _______       __________
# a⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                               _____      __        _______
#                                      - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ____________     __________        __       __________        _______
# ╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \eps
# ──────────────────────────────────────────────────────────────────────────────
#          _____             __           _______                    ___________
# Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ____________                __              _______          ________
# ilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilo
# ──────────────────────────────────────────────────────────────────────────────
# _ __     ____________ _______     ____________   _____       ____________ __
#  ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ____         ____________           ____________            ____________
# n⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c
# ──────────────────────────────────────────────────────────────────────────────
#    ____________ _______
#  ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ____________       __         _______             ____________         __
# ⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            _______                 ____________⎞ _______
#  - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅\Gamma₁               _____
# ──────────────────────────────────────────────────────── - √k⋅p_{in}⋅╲╱ k⋅v  -
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                           ____________ ⎛
#              __             _______                 ⅈ⋅k⋅╲╱ \epsilon⋅k ⋅⎝ⅈ⋅J₁⋅a
#  ⅈ⋅√k⋅p_{in}⋅J₀ - √k⋅p_{in}⋅\Gamma₀ + k⋅p_{in}⋅√v - ──────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                     __________
# + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# __              __            _______       __________          ____________
# k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  +
# ──────────────────────────────────────────────────────────────────────────────
#                    _____      __        _______             _____
#           - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    __________        __       __________        _______                _______
#  ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsil
# ──────────────────────────────────────────────────────────────────────────────
# __           _______                    ____________ __     ____________ _____
# J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____                __              _______          ____________         ___
# on⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \e
# ──────────────────────────────────────────────────────────────────────────────
# __     ____________   _____       ____________ __     ____________ _______
# a₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _________           ____________            ____________           ___________
# psilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _       __         _______             ____________         __           _____
#   - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamm
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# __                 ____________⎞     ⎛
# a₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠   k⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ
# ──────────────────────────────── + ───────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                   ____________              __            ____
#  ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gam
# ──────────────────────────────────────────────────────────────────────────────
#                                                                          _____
#                                                                 - ⅈ⋅J₁⋅╲╱ k⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___       __________          ____________     __________        __       ____
# ma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
#       __        _______             _____             __           _______
#  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______        _______                ____________                __
# silon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#                 ____________ __     ____________ _______     ____________   __
# epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    _______          ____________         ____________           ____________
# ⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  +
# ──────────────────────────────────────────────────────────────────────────────
# ___       ____________ __     ____________ _______
# ⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           ____________           ____________       __         _______
#  ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ____________         __           _______                 ____________⎞ _
# _c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅J
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _       ⎛
# ₁   ⅈ⋅k⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁
# ─ - ──────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#  - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ____________              __            _______       __________
# ⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲
# ──────────────────────────────────────────────────────────────────────────────
#                                               _____      __        _______
#                                      - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ____________     __________        __       __________        _______
# ╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsi
# ──────────────────────────────────────────────────────────────────────────────
#          _____             __           _______                    ___________
# Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         ____________                __              _______          _________
# lon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon
# ──────────────────────────────────────────────────────────────────────────────
# _ __     ____________ _______     ____________   _____       ____________ __
#  ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___         ____________           ____________            ____________
# ⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅
# ──────────────────────────────────────────────────────────────────────────────
#    ____________ _______
#  ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     ____________       __         _______             ____________         __
# w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           _______                 ____________⎞ _______
# - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅\Gamma₁
# ─────────────────────────────────────────────────────── - ⅈ⋅p_{in}⋅√v⋅w + ⅈ⋅p_
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                   ____________ ⎛
#               w⋅╲╱ \epsilon⋅k ⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p
# {in}⋅√v⋅w_b - ────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# _{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Ga
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             ____________              __            _______
# mma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ -
# ──────────────────────────────────────────────────────────────────────────────
#                                                           _____      __
#                                                  - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     __________          ____________     __________        __       __________
# ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#  _______             _____             __           _______
# ⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         _______                ____________                __              ___
# ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Ga
# ──────────────────────────────────────────────────────────────────────────────
#  ____________ __     ____________ _______     ____________   _____       _____
# ╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ____          ____________         ____________           ____________
# mma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅w
# ──────────────────────────────────────────────────────────────────────────────
# _______ __     ____________ _______
# ilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     ____________           ____________       __         _______             _
# ₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___________         __           _______                 ____________⎞       ⎛
# \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠   ⅈ⋅w⋅⎝
# ────────────────────────────────────────────────────────────────────── - ─────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                           ____
# ₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                 _____        __      _______
#                                            J₀⋅╲╱ k⋅v  + ⅈ⋅J₀⋅J₀ + J₀⋅\Gamma₀ +
#
# ________              __            _______       __________          ________
# silon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilo
# ──────────────────────────────────────────────────────────────────────────────
#                                   _____      __        _______             ___
#                          - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅
# ──────────────────────────────────────────────────────────────────────────────
#              _____           __             _______
#  ⅈ⋅\Gamma₀⋅╲╱ k⋅v  - \Gamma₀⋅J₀ + ⅈ⋅\Gamma₀⋅\Gamma₀ + ⅈ⋅a₁⋅b₁ + ⅈ⋅a₁⋅k + a₁⋅w
#
# ____     __________        __       __________        _______                _
# n⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
# __             __           _______                    ____________ __     ___
# v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \e
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  2
# - a₁⋅w_b + ⅈ⋅b₁⋅v + b₁⋅w - b₁⋅wₐ + k⋅w - k⋅wₐ + v⋅w - v⋅w_b - ⅈ⋅w  + ⅈ⋅w⋅wₐ +
#
# ___________                __              _______          ____________
# \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v
# ──────────────────────────────────────────────────────────────────────────────
# _________ _______     ____________   _____       ____________ __     _________
# psilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#                        _____ __       _____ _______
# ⅈ⋅w⋅w_b - ⅈ⋅wₐ⋅w_b + ╲╱ k⋅v ⋅J₀ - ⅈ⋅╲╱ k⋅v ⋅\Gamma₀
#
#    ____________           ____________            ____________           _____
# ⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
# ___ _______
# ⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _______       __         _______             ____________         __
# ilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  _______                 ____________⎞ __     ⎛
# ⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅J₁   w⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w -
# ───────────────────────────────────────── - ──────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#  J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamm
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                            ____________              __
# a₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \del
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                             -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      _______       __________          ____________     __________        __
# ta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ -
# ──────────────────────────────────────────────────────────────────────────────
#        _____      __        _______             _____             __
# ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      __________        _______                ____________                __
#  ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ -
# ──────────────────────────────────────────────────────────────────────────────
#  _______                    ____________ __     ____________ _______     _____
# ⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             _______          ____________         ____________           _____
#  \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
# _______   _____       ____________ __     ____________ _______
# ilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _______            ____________           ____________       __         ______
# ilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _             ____________         __           _______                 ______
# ₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsi
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______⎞ _______         ____________ ⎛
# lon⋅v ⎠⋅\Gamma₁   w_b⋅╲╱ \epsilon⋅k ⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ
# ─────────────── + ────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                   ____________              __            ____
#  ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gam
# ──────────────────────────────────────────────────────────────────────────────
#                                                                _____      __
#                                                       - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___       __________          ____________     __________        __       ____
# ma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \ep
# ──────────────────────────────────────────────────────────────────────────────
#       _______             _____             __           _______
#  ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______        _______                ____________                __
# silon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#       ____________ __     ____________ _______     ____________   _____
# + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
# ...
#
#
# _____           ____________       __         _______             ____________
# on⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          __           _______                 ____________⎞       ____________
#  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠   ⅈ⋅╲╱ \epsilon⋅k
# ─────────────────────────────────────────────────────────── + ────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    _____ ⎛
# ⋅╲╱ k⋅v ⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delt
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       ____________              __            _______       __________
# a⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                 _____      __        _______             _____
#                        - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ____________     __________        __       __________        _______
# ╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \eps
# ──────────────────────────────────────────────────────────────────────────────
#              __           _______                    ____________ __     _____
#  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ____________                __              _______          ________
# ilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilo
# ──────────────────────────────────────────────────────────────────────────────
# _______ _______     ____________   _____       ____________ __     ___________
# ilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ____         ____________           ____________            ____________
# n⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c
# ──────────────────────────────────────────────────────────────────────────────
# _ _______
#  ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      ____________       __         _______             ____________         __
# ⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            _______                 ____________⎞     _____ ⎛
#  - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠   ╲╱ k⋅v ⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a
# ──────────────────────────────────────────────── - ───────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ - J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                         ____________
# a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ - ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delt
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     __            _______       __________          ____________     _________
# a⋅c⋅J₁ - \delta⋅c⋅\Gamma₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon
# ──────────────────────────────────────────────────────────────────────────────
#               _____      __        _______             _____             __
#      - ⅈ⋅J₁⋅╲╱ k⋅v  + J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _        __       __________        _______                ____________
#  ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\e
# ──────────────────────────────────────────────────────────────────────────────
#         _______                    ____________ __     ____________ _______
# \Gamma₁⋅\Gamma₀ + \epsilon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          __              _______          ____________         ____________
# psilon⋅c⋅J₁ - \epsilon⋅c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  -
# ──────────────────────────────────────────────────────────────────────────────
#   ____________   _____       ____________ __     ____________ _______
# ╲╱ \epsilon⋅v ⋅╲╱ k⋅v  - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         ____________            ____________           ____________       __
# ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  + ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        _______             ____________         __           _______
#  ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        ____________⎞ __       _____ ⎛
# }⋅√v⋅╲╱ \epsilon⋅v ⎠⋅J₁   ⅈ⋅╲╱ k⋅v ⋅⎝ⅈ⋅J₁⋅a⋅a₁ + ⅈ⋅J₁⋅a⋅v + J₁⋅a⋅w - J₁⋅a⋅wₐ -
# ─────────────────────── + ────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#  J₁⋅p_{in}⋅√v - \Gamma₁⋅a⋅a₁ - \Gamma₁⋅a⋅v + ⅈ⋅\Gamma₁⋅a⋅w - ⅈ⋅\Gamma₁⋅a⋅wₐ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                  ____________              __            _____
# ⅈ⋅\Gamma₁⋅p_{in}⋅√v - \delta⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\delta⋅c⋅J₁ - \delta⋅c⋅\Gamm
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        _____
#                                                               - ⅈ⋅J₁⋅╲╱ k⋅v  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# __       __________          ____________     __________        __       _____
# a₁ - ⅈ⋅╲╱ \epsilon ⋅p_{in}⋅╲╱ \epsilon⋅k  + ╲╱ \epsilon ⋅p_{in}⋅J₁ - ⅈ⋅╲╱ \eps
# ──────────────────────────────────────────────────────────────────────────────
#     __        _______             _____             __           _______
#  J₁⋅J₀ - ⅈ⋅J₁⋅\Gamma₀ + \Gamma₁⋅╲╱ k⋅v  + ⅈ⋅\Gamma₁⋅J₀ + \Gamma₁⋅\Gamma₀ + \ep
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____        _______                ____________                __
# ilon ⋅p_{in}⋅\Gamma₁ - \epsilon⋅c⋅╲╱ \epsilon⋅k  - ⅈ⋅\epsilon⋅c⋅J₁ - \epsilon⋅
# ──────────────────────────────────────────────────────────────────────────────
#               ____________ __     ____________ _______     ____________   ____
# silon⋅k + ⅈ⋅╲╱ \epsilon⋅k ⋅J₁ + ╲╱ \epsilon⋅k ⋅\Gamma₁ - ╲╱ \epsilon⋅v ⋅╲╱ k⋅v
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   _______          ____________         ____________           ____________
# c⋅\Gamma₁ + a⋅a₁⋅╲╱ \epsilon⋅v  + a⋅v⋅╲╱ \epsilon⋅v  - ⅈ⋅a⋅w⋅╲╱ \epsilon⋅v  +
# ──────────────────────────────────────────────────────────────────────────────
# _       ____________ __     ____________ _______
#   - ⅈ⋅╲╱ \epsilon⋅v ⋅J₀ - ╲╱ \epsilon⋅v ⋅\Gamma₀
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ____________           ____________       __         _______
# ⅈ⋅a⋅wₐ⋅╲╱ \epsilon⋅v  + ⅈ⋅c⋅w⋅╲╱ \epsilon⋅k  - c⋅w⋅J₁ + ⅈ⋅c⋅w⋅\Gamma₁ - ⅈ⋅c⋅w_
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     ____________         __           _______                 ____________⎞ __
# c⋅╲╱ \epsilon⋅k  + c⋅w_c⋅J₁ - ⅈ⋅c⋅w_c⋅\Gamma₁ + ⅈ⋅p_{in}⋅√v⋅╲╱ \epsilon⋅v ⎠⋅\G
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____⎞
# amma₁⎟
# ─────⎟
#      ⎟
#      ⎠
# ────── = 0

# %%
import pickle

# Load the pickled objects
with open('equations_and_solutions.pkl', 'rb') as f:
    loaded_objects = pickle.load(f)

# Dynamically assign each object to its original name
globals().update(loaded_objects)

# Now eq1, eq2, ..., solution1, solution2, etc. are available with their original names

# %%
solution4 = sp.solve(new_eq_substituted, pout)
solution4[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 solution4 = sp.solve(new_eq_substituted, pout)
#       2 solution4[0]
#
# File ~\miniconda3\Lib\site-packages\sympy\solvers\solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File ~\miniconda3\Lib\site-packages\sympy\solvers\solvers.py:1434, in _solve(f, *symbols, **flags)
#    1431 elif f_num.is_Symbol:
#    1432     # no need to check but simplify if desired
#    1433     if flags.get('simplify', True):
# -> 1434         sol = simplify(sol)
#    1435     return [{f_num: sol}]
#    1437 poly = None
#
# File ~\miniconda3\Lib\site-packages\sympy\simplify\simplify.py:644, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     642 expr = _bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     643 expr = Mul(*powsimp(expr).as_content_primitive())
# --> 644 _e = cancel(expr)
#     645 expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     646 expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\polytools.py:6890, in cancel(f, _signsimp, *gens, **args)
#    6887                 pass
#    6888         return f.xreplace(dict(reps))
# -> 6890 c, (P, Q) = 1, F.cancel(G)
#    6891 if opt.get('polys', False) and 'gens' not in opt:
#    6892     opt['gens'] = R.symbols
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\rings.py:2193, in PolyElement._gcd(f, g)
#    2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
# -> 2193     return ring.dmp_inner_gcd(f, g)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\compatibility.py:663, in IPolys.dmp_inner_gcd(self, f, g)
#     662 def dmp_inner_gcd(self, f, g):
# --> 663     H, F, G = dmp_inner_gcd(self.to_dense(f), self.to_dense(g), self.ngens-1, self.domain)
#     664     return (self.from_dense(H), self.from_dense(F), self.from_dense(G))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1557, in _dmp_inner_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
# -> 1557 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1060, in dmp_rr_prs_gcd(f, g, u, K)
#    1057 if not u:
#    1058     return dup_rr_prs_gcd(f, g, K)
# -> 1060 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1062 if result is not None:
#    1063     return result
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:954, in _dmp_simplify_gcd(f, g, u, K)
#     952         G = dmp_content(g, u, K)
#     953     else:
# --> 954         F = dmp_content(f, u, K)
#     955         G = dmp_LC(g, K)
#     957 v = u - 1
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1557, in _dmp_inner_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
# -> 1557 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1066, in dmp_rr_prs_gcd(f, g, u, K)
#    1063     return result
#    1065 fc, F = dmp_primitive(f, u, K)
# -> 1066 gc, G = dmp_primitive(g, u, K)
#    1068 h = dmp_subresultants(F, G, u, K)[-1]
#    1069 c, _, _ = dmp_rr_prs_gcd(fc, gc, u - 1, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1818, in dmp_primitive(f, u, K)
#    1804 def dmp_primitive(f, u, K):
#    1805     """
#    1806     Returns multivariate content and a primitive polynomial.
#    1807
#    (...)
#    1816
#    1817     """
# -> 1818     cont, v = dmp_content(f, u, K), u - 1
#    1820     if dmp_zero_p(f, u) or dmp_one_p(cont, v, K):
#    1821         return cont, f
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1557, in _dmp_inner_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
# -> 1557 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:1068, in dmp_rr_prs_gcd(f, g, u, K)
#    1065 fc, F = dmp_primitive(f, u, K)
#    1066 gc, G = dmp_primitive(g, u, K)
# -> 1068 h = dmp_subresultants(F, G, u, K)[-1]
#    1069 c, _, _ = dmp_rr_prs_gcd(fc, gc, u - 1, K)
#    1071 if K.is_negative(dmp_ground_LC(h, u, K)):
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:1238, in dmp_prem(f, g, u, K)
#    1235 j, N = dr - dg, N - 1
#    1237 R = dmp_mul_term(r, lc_g, 0, u, K)
# -> 1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#    1241 _dr, dr = dr, dmp_degree(r, u)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (15 times)]
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densearith.py:565, in dmp_add(f, g, u, K)
#     562 if not u:
#     563     return dup_add(f, g, K)
# --> 565 df = dmp_degree(f, u)
#     567 if df < 0:
#     568     return g
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densebasic.py:178, in dmp_degree(f, u)
#     157 def dmp_degree(f, u):
#     158     """
#     159     Return the leading degree of ``f`` in ``x_0`` in ``K[X]``.
#     160
#    (...)
#     176
#     177     """
# --> 178     if dmp_zero_p(f, u):
#     179         return -oo
#     180     else:
#
# File ~\miniconda3\Lib\site-packages\sympy\polys\densebasic.py:710, in dmp_zero_p(f, u)
#     695 def dmp_zero_p(f, u):
#     696     """
#     697     Return ``True`` if ``f`` is zero in ``K[X]``.
#     698
#    (...)
#     708
#     709     """
# --> 710     while u:
#     711         if len(f) != 1:
#     712             return False
#
# KeyboardInterrupt:

# %%
# Solve equation eq5 for s21 after substituting pout from solution3
solution5 = sp.solve(eq7.subs(pout, solution4[0]), s21)

# Assign the value of s21 to a variable
S = solution5[0]
S

# Print the value of s21
#print(S)

# %%
wn=np.linspace(3,7,1000)
Sfunc = sp.lambdify([w,wb],S.subs({v:0.0004,k:0.001,wa:3,b1:0.001,a1:0.003,d:2,d2:2,c1:.002}) )
for wm_n in [4]:
        plt.plot(wn,np.abs(Sfunc(wn,wm_n)))

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

d_value=0.1    # coupling strength between photon (cavity) and magnon mode d=j+if'  where f'= f+sqrt(vk)
k_value=0.001   # extrinsic damping of magnon mode
v_value=0.009  #gamma extrinsic damping of cavity
wa_value=5.33     # cavity resonance frequency 
b1_value=0.014 # intrinsic damping of magnon mode

a1_value=0.0046*(1+(d_value**2)/(b1_value*0.046*5.33*5.33))  # intrinsic damping of cavity 

s21_1=S.subs({v:v_value,wa:wa_value,a1:a1_value,b1:b1_value,k:k_value,d:d_value})


# Define parameter ranges
H_values = np.linspace(1.000, 1.350, 101)
w_values = np.linspace(4.5, 6, 1001)

# Convert symbolic expression s21 to a NumPy function
s21_func = sp.lambdify((w, wb), sp.Abs(s21_1), modules='numpy')

# Initialize a list to store s21_f
s21_f = []

# Loop over each H value
for H in H_values:
    # Calculate wb_value for the current H value
    #wb_value = 2.8*np.sqrt(H * (H + 0.172))
    wb_value=1.38284384+(3.24789744)*H
    
    # Initialize a list to store s21_3 values for the current H value
    s21_f_H = []
    
    for w_val in w_values:
        s21_2 = s21_func(w_val, wb_value)
        s21_f_H.append(s21_2)
      
    # Append s21_f_H to s21_f as a row
    s21_f.append(s21_f_H)

# Convert s21_f to a numpy array and transpose it
s21_f = np.array(s21_f).T  # Transpose s21_f here
H_f = np.array(H_values)
w_f = np.array(w_values)

# Create a contour plot
#contour = plt.contourf(H_f, w_f, s21_f, )
contour = plt.contourf(H_f, w_f, s21_f, cmap='jet', levels=np.linspace(0, 2, 501))
plt.colorbar(contour)
plt.xlabel('H')
plt.ylabel('w')
plt.title('Contour Plot of s21')
plt.show()

#print(s21_f)
#print(H_f)
#print(w_f)
#s21_f.shape[0]
#H_f.shape[0]
#plt.ylim([3.6, 4.4])
#plt.xlim([1250, 1450])
# plt.clim(-7, 0)

# %%
import sympy as sp
import numpy as np

J, gamma = sp.symbols('J, gamma') # d=J+j*gamma
# Define given values
J_value = 0.03
gamma_value = 0.0


# Define the equations
w_plus = ((wa + wb) - j * (a1 + b1 + v + k) + sp.sqrt(4 * (J + j * gamma)**2 + ((wa - wb) - j * (a1 + v - b1 - k))**2)) / 2
w_minus = ((wa + wb) - j * (a1 + b1 + v + k) - sp.sqrt(4 * (J + j * gamma)**2 + ((wa - wb) - j * (a1 + v - b1 - k))**2)) / 2

# Substitute known values into the equations
w_plus_sub = w_plus.subs({v: v_value, wa: wa_value, a1: a1_value, b1: b1_value, k: k_value, J: J_value, gamma: gamma_value})
w_minus_sub = w_minus.subs({v: v_value, wa: wa_value, a1: a1_value, b1: b1_value, k: k_value, J: J_value, gamma: gamma_value})

# Create a lambdified function for w_plus
w_plus_func = sp.lambdify(wb, sp.re(w_plus_sub), modules='numpy')
w_minus_func = sp.lambdify(wb, sp.re(w_minus_sub), modules='numpy')


# Define H values
H_values = np.linspace(0.720, 0.920, 101)
w_plus_results = []
w_minus_results = []

# Loop through H values and calculate w_plus2
for H in H_values:
    wb_value = 1.38284384 + (3.24789744) * H
    
    w_plus2 = w_plus_func(wb_value)
    w_minus2 = w_minus_func(wb_value)
    
    w_plus_results.append(w_plus2)
    w_minus_results.append(w_minus2)

    
plt.plot(H_values,w_plus_results);plt.plot(H_values,w_minus_results)   

# Plot the results
plt.plot(H_values, w_plus_results, label='w_plus')
plt.plot(H_values, w_minus_results, label='w_minus')
plt.xlabel('H Values')
plt.ylabel('w_plus and w_minus')
plt.legend()
plt.show()

# %%
J, gamma = sp.symbols('J, gamma') # d=J+j*gamma
J_value = 0.0
gamma_value = 0.03


# Define the equations
w_plus = ((wa + wb) - j * (a1 + b1 + v + k) + sp.sqrt(4 * (J + j * gamma)**2 + ((wa - wb) - j * (a1 + v - b1 - k))**2)) / 2
w_minus = ((wa + wb) - j * (a1 + b1 + v + k) - sp.sqrt(4 * (J + j * gamma)**2 + ((wa - wb) - j * (a1 + v - b1 - k))**2)) / 2

# Substitute known values into the equations
w_plus_func = sp.lambdify(wb, sp.im(w_plus.subs({v: v_value, wa: wa_value, a1: a1_value, b1: b1_value, k: k_value, J: J_value, gamma: gamma_value})), modules='numpy')
w_minus_func = sp.lambdify(wb, sp.im(w_minus.subs({v: v_value, wa: wa_value, a1: a1_value, b1: b1_value, k: k_value, J: J_value, gamma: gamma_value})), modules='numpy')

# Define H values
H_values = np.linspace(0.720, 0.920, 101)

# Calculate w_plus and w_minus for each H value
w_plus_results = [w_plus_func(1.38284384 + (3.24789744) * H) for H in H_values]
w_minus_results = [w_minus_func(1.38284384 + (3.24789744) * H) for H in H_values]

# Plot the results
plt.plot(H_values, w_plus_results, label='w_plus')
plt.plot(H_values, w_minus_results, label='w_minus')
plt.xlabel('H Values')
plt.ylabel('w_plus and w_minus')
plt.legend()
plt.show()
